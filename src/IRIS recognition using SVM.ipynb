# %% [markdown]
# ## Documentation
#
# This code implements an IRIS recognition system using the Support Vector Machine (SVM) algorithm on the CASIA1 dataset. The code loads the images from the dataset, splits the dataset into features and target variables, and then splits the features and target variables into training and testing sets. The model is trained using the SVM algorithm on the training set, and the iris class is predicted for the testing set. The accuracy of the model is then calculated using the accuracy_score function from the sklearn.metrics library.

# %%
import numpy as np
import cv2
import os
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn import metrics
import matplotlib.pyplot as plt

# %%
# Load the dataset
dataset_path = "/Users/samarpan/Documents/GitHub/IOT-Based-Smart-Security-Solution/src/CASIA1"
images = []
labels = []
for folder in os.listdir(dataset_path):
    folder_path = os.path.join(dataset_path, folder)
    for image_path in os.listdir(folder_path):
        image = cv2.imread(os.path.join(folder_path, image_path), 0)
        image = cv2.resize(image, (64, 64))
        images.append(image.flatten())
        labels.append(folder)

# %%
# Split the dataset into features and target variables
features = np.array(images)
target = np.array(labels)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=0)

# Train the model using Support Vector Machine (SVM) algorithm
#classifier = SVC()
history = classifier.fit(X_train, y_train)

# Predict the iris class using the trained model
y_pred = classifier.predict(X_test)

# %%
# Calculate the accuracy of the model
#accuracy = accuracy_score(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy of the SVM version of model:", accuracy*100, "%")
# Out:
# Accuracy of the SVM version of model: 30.92105263157895 %

# %%
print(history)
# Out:
# SVC()

# %%
# Plot the confusion matrix
cm = metrics.confusion_matrix(y_test, y_pred)
plt.imshow(cm, cmap=plt.cm.Blues)
plt.colorbar()

# %%
# experimentation
# Plot the confusion matrix
cm = metrics.confusion_matrix(y_test, y_pred)
plt.imshow(cm)
plt.colorbar()

# %%
# Accuracy plot
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-760ac7ca0c58> in <module>
#       1 # Accuracy plot
# ----> 2 plt.plot(history.history['accuracy'])
#       3 plt.plot(history.history['val_accuracy'])
#       4 plt.title('Model accuracy')
#       5 plt.ylabel('Accuracy')
#
# AttributeError: 'SVC' object has no attribute 'history'

# %%
# Loss plot
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
